# %% [markdown]
# # Learn Python Programming For Data Science
# 1-Download the python using link (https://www.python.org/downloads/).<br>
# 2-Download the Anaconda using link (https://www.anaconda.com/).<br>
# 3-TO install anaconda anywhere and to open anaconda and to lounch jupyter notebook.<br>
# 4-To make a folder anywhere and to open and search jupyter notebook.

# %% [markdown]
# ## Arithmatic Operators in Python.
# ![image.png](attachment:715d57b2-4d17-43da-87bb-9bf7925f9589.png)

# %% [markdown]
# ![image.png](attachment:86e487a6-b6fb-4f53-9721-dbe2c39a168e.png)

# %% [markdown]
# ## Logical Operators In python
# ![image.png](attachment:2a8c0785-665f-4046-ba82-ed36d6209720.png)
# ![image.png](attachment:70ee2b0b-59df-4535-899b-9b52b58c8e40.png)

# %% [markdown]
# ## Assighnment Operators In python.
# ![image.png](attachment:5e8f9bc7-f368-48f3-9eee-f5ea621e57da.png)

# %% [markdown]
# ## IF Else Staements in Python.
# ![image.png](attachment:e9784ef7-e8c1-4d62-9bd9-d1791e7a6b05.png)

# %% [markdown]
# ## IF Elif Statements In python.
# ![image.png](attachment:6eaa285a-9533-4573-999f-75acb782c5e0.png)

# %% [markdown]
# ## List in Python
# ![image.png](attachment:50f93fa2-ebd5-4711-8267-f6f9ec4f0654.png)
# ![image.png](attachment:33f46c69-77d3-4ea5-a9f5-5eaab21d292f.png)

# %% [markdown]
# ## Silicing In python In List.
# ![image.png](attachment:5289a73e-b351-42c5-990c-064d9cd3ae91.png)

# %% [markdown]
# ## ![image.png](attachment:0171ec44-3f5b-4b67-80ad-a7924991a093.png)

# %% [markdown]
# ## Tuple in python
# ![image.png](attachment:29e6cea7-06c9-4776-ae13-7628616b1544.png)
# ![image.png](attachment:8c1795fb-04a3-400c-90db-43680925f52d.png)

# %% [markdown]
# ## Dictionary in python
# ![image.png](attachment:6eaac270-06ca-4713-9bbf-f9ca27b5d669.png)

# %% [markdown]
# ## For Loop in python.
# ![image.png](attachment:998b3b7e-72bc-471c-9d9b-3fdcdc583ead.png)

# %% [markdown]
# ## While Loop in python.
# ![image.png](attachment:7cbac753-9687-40d8-bb04-ee17de6201b0.png)

# %% [markdown]
# ##  List compression in python
# ![image.png](attachment:49f19962-9283-4ea0-aec2-c97891ca91a7.png)

# %% [markdown]
# ##
# lambda functions in pytho
#
#
# ![image.png](attachment:81b65ba1-e532-4ce6-9300-8c67e3a4a701.png)

# %% [markdown]
# #  Object Oriented Languages (OOPS) in python
# ![image.png](attachment:2737c445-0839-4f35-b265-bc127bc6b26a.png)irst_name
# 'Muhammad'

# %%
class team():
    def __init__(self,first_name,last_name,age):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
    def age(self):
        if self.age>10:
            print(f"{self.first_name},{self.last_name} player is ok {self.age}")
        else:
            print(f"{self.first_name},{self.last_name} player is not ok {self.age}")
    def change_name(self, update_first_name):
        self.first_name = update_first_name

# %%
players = team('bilal','hassan',10)

# %%
players.first_name
# Out:
# 'bilal'

# %%
players.age
# Out:
# 10

# %%
players.change_name('Muhammad')

# %%
players.first_name
# Out:
# 'Muhammad'

# %% [markdown]
# ## File Handling in python
# ![image.png](attachment:a9f8257c-0c50-4ab4-a4ab-c74486ddb6f3.png)
